# %%
import pandas as pd
import re

# 파일 불러오기
officetels = pd.read_csv("C:/Users/user/Desktop/Final_Project/data/officetels/officetels123.csv")
officetels
# Out:
#         id    road_address                          건물이름   longitude  \
# 0        1  디지털로32가길 76-30                            유림  126.897470
# 1        2         난계로 169                      DUO302\t  127.023322
# 2        3         자곡로 192  강남 푸르지오시티 2차(PRUGIO CITYⅡ)\t  127.104143
# 3        4     디지털로32다길 50                 골드마인(Ⅲ)오피스텔\t  126.898620
# 4        5        도영로 16-1            \t도림동 하나 아파텔(2차)\t  126.896157
# ...    ...             ...                           ...         ...
# 1603  1604          영중로 21                  HIGHEND 63st  126.905281
# 1604  1605       영신로40길 18                         윤성타워텔  126.903290
# 1605  1606        영신로42길 7                         케이디타워  126.902754
# 1606  1607        영신로40길 7                         현대하이츠  126.902260
# 1607  1608         영중로 134                           신현빌  126.906039
#
#        latitude category
# 0     37.481297     오피스텔
# 1     37.566451     오피스텔
# 2     37.474623     오피스텔
# 3     37.480951     오피스텔
# ...

# %%
print("결측치 개수:")
print(officetels.isnull().sum())
# Out:
# 결측치 개수:
# id              0
# road_address    0
# 건물이름            0
# longitude       0
# latitude        0
# category        0
# dtype: int64
