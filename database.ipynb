# %%
import chardet

with open("safety.csv", "rb") as f:
    result = chardet.detect(f.read(10000))
    print(result)  # {'encoding': 'cp949', 'confidence': 0.99}
# Out:
# {'encoding': 'utf-8', 'confidence': 0.99, 'language': ''}
