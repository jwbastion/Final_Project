# %%
import pandas as pd
import re

# 파일 불러오기
cinema = pd.read_csv("../data/play/cinema.csv")
pc = pd.read_csv("../data/play/pc.csv")
sing = pd.read_csv("../data/play/sing.csv")

# %%
# 주제 추가
cinema['category'] = '영화관'
pc['category'] = 'PC방'
sing['category'] = '노래방'

# %%
# 통합
play_df = pd.concat([cinema, pc, sing], ignore_index=True)

# %%
# 컬럼명 변경
# land_address   : 지번 주소
# road_address   : 도로명 주소
# postal_code    : 도로명 우편번호
# business_name  : 사업장 이름
# longitude      : 경도
# latitude       : 위도
# category       : 업종 분류 (영화관 / PC방 / 노래방)
play_df.columns = ['land_address', 'road_address', 'postal_code', 'business_name', 'longitude', 'latitude', 'category']

# %%
print(play_df.nunique()) # 고유 값 개수
# Out:
# land_address     8020
# road_address     8007
# postal_code      2030
# business_name    5492
# longitude        7047
# latitude         7047
# category            3
# dtype: int64

# %%
print("결측치 개수:")
print(play_df.isnull().sum())
# Out:
# 결측치 개수:
# land_address        8
# road_address      151
# postal_code      3276
# business_name       0
# longitude         464
# latitude          464
# category            0
# dtype: int64

# %% [markdown]
# 위경도 부분 464개의 결측치

# %%
print(play_df.sample(5)) # 샘플 데이터 확인
# Out:
#                           land_address  \
# 3880      서울특별시 노원구 공릉동 633-15 경동상가 2층
# 356                 서울특별시 동대문구 휘경동 329
# 2474  서울특별시 강남구 역삼동 723-7번지 CNY빌딩 지하1층
# 4519        서울특별시 영등포구 영등포동5가 28번지 2층호
# 1938  서울특별시 구로구 구로동 413-1 설록빌딩 1층 102호
#
#                                    road_address postal_code business_name  \
# 3880           서울특별시 노원구 공릉로 101, 경동상가 2층 (공릉동)        1849  맥스피드PC방 태릉역점
# 356             서울특별시 동대문구 회기로28길 8, 지하1층 (휘경동)        2446         제노PC방
# 2474                서울특별시 강남구 언주로85길 23-6 (역삼동)        6222      피크PC방 역삼
# 4519          서울특별시 영등포구 영등포로37길 8, 2층 (영등포동5가)        7250          행운PC
# 1938  서울특별시 구로구 가마산로12길 8-3, 설록빌딩 1층 102호 (구로동)        8309          세븐PC
#
#        longitude   latitude category
# 3880  127.077842  37.619301      PC방
# 356   127.055945  37.589461      PC방
# 2474  127.041366  37.500464      PC방
# 4519  126.905548  37.520873      PC방
# 1938  126.882549  37.492432      PC방

# %%
# 우편번호 정제
def clean_postal_code(x):
    if pd.isna(x):
        return pd.NA
    digits = re.sub(r'[^0-9]', '', str(x))
    return digits.zfill(5) if len(digits) == 5 else pd.NA

# %%
play_df['postal_code'] = play_df['postal_code'].apply(clean_postal_code)

# %%
# 위도/경도 결측치 제거
play_df = play_df.dropna(subset=['longitude', 'latitude'])

# %%
# ID 컬럼 추가
play_df.reset_index(drop=True, inplace=True)
play_df.insert(0, 'id', play_df.index + 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_4616\2358048808.py in ?()
#       1 # ID 컬럼 추가
#       2 play_df.reset_index(drop=True, inplace=True)
# ----> 3 play_df.insert(0, 'id', play_df.index + 1)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ...

# %%
# land_address, postal_code 열 제거
play_df.drop(columns=['land_address', 'postal_code'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # land_address, postal_code 열 제거
# ----> 2 play_df.drop(columns=['land_address', 'postal_code'], inplace=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
# 정제된 결과 확인
print("\n 정제 후 데이터 개수:", len(play_df))
# Out:
#  정제 후 데이터 개수: 10374

# %%
# 저장
play_df.to_csv("../data/play/play.csv", index=False, encoding='utf-8-sig')

# %%
import pandas as pd

df = pd.read_csv("../data/play/play.csv")

print("전체 컬럼별 결측치 개수:")
print(df.isnull().sum())

print("\n 결측치가 있는 행:")
print(df[df.isnull().any(axis=1)])
# Out:
# 전체 컬럼별 결측치 개수:
# id               0
# road_address     0
# business_name    0
# longitude        0
# latitude         0
# category         0
# dtype: int64
#
#  결측치가 있는 행:
# Empty DataFrame
# Columns: [id, road_address, business_name, longitude, latitude, category]
# Index: []
