# %%
import pandas as pd
import re

# 파일 불러오기
play = pd.read_csv("../data/play/play.csv")

# %%
# 주제 추가
cinema['category'] = '영화관'
pc['category'] = 'PC방'
sing['category'] = '노래방'

# %%
# 통합
play_df = pd.concat([cinema, pc, sing], ignore_index=True)

# %%
# 컬럼명 변경
# land_address   : 지번 주소
# road_address   : 도로명 주소
# postal_code    : 도로명 우편번호
# business_name  : 사업장 이름
# longitude      : 경도
# latitude       : 위도
# category       : 업종 분류 (영화관 / PC방 / 노래방)
play_df.columns = ['land_address', 'road_address', 'postal_code', 'business_name', 'longitude', 'latitude', 'category']

# %%
print(play_df.nunique()) # 고유 값 개수
# Out:
# land_address     8020
# road_address     8007
# postal_code      2030
# business_name    5492
# longitude        7047
# latitude         7047
# category            3
# dtype: int64

# %%
print("결측치 개수:")
print(play_df.isnull().sum())
# Out:
# 결측치 개수:
# land_address        8
# road_address      151
# postal_code      3276
# business_name       0
# longitude         464
# latitude          464
# category            0
# dtype: int64

# %% [markdown]
# 위경도 부분 464개의 결측치

# %%
print(play_df.sample(5)) # 샘플 데이터 확인
# Out:
#                              land_address  \
# 978         서울특별시 성동구 금호동1가 1756-1 금호연풍교회
# 845                   서울특별시 강북구 번동 443-13
# 1949                 서울특별시 구로구 구로동 30-0번지
# 5301  서울특별시 강동구 길동 474번지 GS강동자이아파트상가 204호
# 590               서울특별시 중랑구 중화동 315-10 2층
#
#                                        road_address postal_code business_name  \
# 978          서울특별시 성동구 금호로 86, 금호연풍교회 2층 나호 (금호동1가)        4718      1프로PC아레나
# 845                     서울특별시 강북구 오패산로 385, 2층 (번동)        1069          황금PC
# 1949                     서울특별시 구로구 새말로16길 15  (구로동)         NaN          해커스랩
# 5301  서울특별시 강동구 천호대로199길 10, 204호 (길동, GS강동자이아파트상가)        5348           쟈스민
# 590                     서울특별시 중랑구 중랑역로 51 (중화동, 2층)        2104     뉴본PC CAFE
#
#        longitude   latitude category
# 978   127.025769  37.551212      PC방
# 845   127.028073  37.635747      PC방
# 1949  126.890630  37.504969      PC방
# 5301  127.148033  37.537103      PC방
# 590   127.076920  37.598378      PC방

# %%
# 우편번호 정제
def clean_postal_code(x):
    if pd.isna(x):
        return pd.NA
    digits = re.sub(r'[^0-9]', '', str(x))
    return digits.zfill(5) if len(digits) == 5 else pd.NA

# %%
play_df['postal_code'] = play_df['postal_code'].apply(clean_postal_code)

# %%
# 위도/경도 결측치 제거
play_df = play_df.dropna(subset=['longitude', 'latitude'])

# %%
# ID 컬럼 추가
play_df.reset_index(drop=True, inplace=True)
play_df.insert(0, 'id', play_df.index + 1)

# %%
# 정제된 결과 확인
print("\n 정제 후 데이터 개수:", len(play_df))
# Out:
#  정제 후 데이터 개수: 10374

# %%
# 저장
play_df.to_csv("../data/play/play.csv", index=False, encoding='utf-8-sig')

# %%
import pandas as pd

df = pd.read_csv("../data/play/play.csv")

print("전체 컬럼별 결측치 개수:")
print(df.isnull().sum())

print("\n 결측치가 있는 행:")
print(df[df.isnull().any(axis=1)])
# Out:
# 전체 컬럼별 결측치 개수:
# id                   0
# land_address         8
# road_address         0
# postal_code      10311
# business_name        0
# longitude            0
# latitude             0
# category             0
# dtype: int64
#
#  결측치가 있는 행:
#           id                  land_address                       road_address  \
# 1          2  서울특별시 강남구 역삼동 814-6 스타플렉스 8층  서울특별시 강남구 강남대로 438 (역삼동,스타플렉스 8층)
# 3          4           서울특별시 강남구 신사동 603-2            서울특별시 강남구 논현로 848 (신사동)
# 4          5           서울특별시 강남구 논현동 1-3번지          서울특별시 강남구 도산대로 108  (논현동)
# 5          6          서울특별시 강남구 논현동 3 외2필지      서울특별시 강남구 도산대로 116 (논현동,외2필지)
# 6          7          서울특별시 강남구 논현동 4-15번지          서울특별시 강남구 도산대로 128  (논현동)
# ...      ...                           ...                                ...
# 10369  10370        서울특별시 은평구 역촌동 34-34 지층           서울특별시 은평구 연서로4길 17 (역촌동)
# 10370  10371           서울특별시 광진구 중곡동 242-1          서울특별시 광진구 긴고랑로 42-1 (중곡동)
# 10371  10372              서울특별시 송파구 가락동 76   서울특별시 송파구 양재대로62길 47, 지하1층 (가락동)
# 10372  10373         서울특별시 은평구 대조동 33-1 지층          서울특별시 은평구 진흥로13길 13 (대조동)
# 10373  10374        서울특별시 중구 무학동 32-1 지상2층      서울특별시 중구 퇴계로76길 24 (무학동,지상2층)
#
#        postal_code  business_name   longitude   latitude category
# 1              NaN         CGV 강남  127.026336  37.501643      영화관
# 3              NaN         CGV압구정  127.028837  37.524574      영화관
# 4              NaN  클래식시네마스페이스(주)  127.020656  37.516192      영화관
# 5              NaN     메가박스 브로드웨이  127.021516  37.516607      영화관
# 6              NaN          씨네마강남  127.022706  37.516972      영화관
# ...            ...            ...         ...        ...      ...
# 10369          NaN       옥소리노래연습장  126.917793  37.602687      노래방
# 10370          NaN        퀸 노래연습장  127.081024  37.562554      노래방
# 10371          NaN       행운 노래연습장  127.120734  37.496025      노래방
# 10372          NaN       황금2노래연습장  126.925000  37.609529      노래방
# 10373          NaN      오렌지 노래연습장  127.015331  37.564185      노래방
#
# [10311 rows x 8 columns]

# %%
play = pd.read_csv("../data/play/play.csv")

# %%
df.drop(columns=['land_address'], inplace=True)
print(df.columns)
# Out:
# Index(['id', 'road_address', 'business_name', 'longitude', 'latitude',
#        'category'],
#       dtype='object')

# %%
play.to_csv("../data/play/play.csv", index=False, encoding='utf-8')
